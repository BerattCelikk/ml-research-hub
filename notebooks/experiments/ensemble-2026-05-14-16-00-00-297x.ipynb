# %% [markdown]
# # 🎭 Ensemble Methods
#
# **Session:** 2026-05-14-16-00-00-297x
# **Date:** 2026-05-14

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

EXP_ID = "2026-05-14-16-00-00-297x"
TOPIC = "Ensemble Methods"
print(f"Experiment: {EXP_ID}")

# %%
config = {
  "topic": "ensemble",
  "learning_rate": 0.0003,
  "batch_size": 256,
  "epochs": 50,
  "optimizer": "adam",
  "seed": 76
}
print(config)

# %%
# Results
results = {
  "accuracy": 0.8970,
  "loss": 0.01883,
  "iterations": 3486,
  "epoch": 37
}
print("Results:", results)

# %% [markdown]
# ## Summary
#
# - Accuracy: **0.8970**
# - Loss: **0.01883**
# - Epoch: 37/50
