# %% [markdown]
# # 🔬 Neural Network
#
# **Session:** 2026-05-16-18-25-48-mzm0
# **Date:** 2026-05-16

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

EXP_ID = "2026-05-16-18-25-48-mzm0"
TOPIC = "Neural Network"
print(f"Experiment: {EXP_ID}")

# %%
config = {
  "topic": "neural-network",
  "learning_rate": 0.003,
  "batch_size": 32,
  "epochs": 50,
  "optimizer": "adam",
  "seed": 78
}
print(config)

# %%
# Results
results = {
  "accuracy": 0.9051,
  "loss": 0.03364,
  "iterations": 3546,
  "epoch": 39
}
print("Results:", results)

# %% [markdown]
# ## Summary
#
# - Accuracy: **0.9051**
# - Loss: **0.03364**
# - Epoch: 39/50
