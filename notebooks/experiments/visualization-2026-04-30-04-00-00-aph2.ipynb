# %% [markdown]
# # 📈 Visualization
#
# **Session:** 2026-04-30-04-00-00-aph2
# **Date:** 2026-04-30

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

EXP_ID = "2026-04-30-04-00-00-aph2"
TOPIC = "Visualization"
print(f"Experiment: {EXP_ID}")

# %%
config = {
  "topic": "visualization",
  "learning_rate": 0.01,
  "batch_size": 256,
  "epochs": 50,
  "optimizer": "adam",
  "seed": 62
}
print(config)

# %%
# Results
results = {
  "accuracy": 0.9025,
  "loss": 0.07905,
  "iterations": 3092,
  "epoch": 23
}
print("Results:", results)

# %% [markdown]
# ## Summary
#
# - Accuracy: **0.9025**
# - Loss: **0.07905**
# - Epoch: 23/50
