# %% [markdown]
# # ✂️ Model Pruning
#
# **Session:** 2026-04-21-00-48-06-nyw9
# **Date:** 2026-04-21

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

EXP_ID = "2026-04-21-00-48-06-nyw9"
TOPIC = "Model Pruning"
print(f"Experiment: {EXP_ID}")

# %%
config = {
  "topic": "model-pruning",
  "learning_rate": 0.0001,
  "batch_size": 128,
  "epochs": 50,
  "optimizer": "adam",
  "seed": 54
}
print(config)

# %%
# Results
results = {
  "accuracy": 0.9703,
  "loss": 0.06617,
  "iterations": 2904,
  "epoch": 15
}
print("Results:", results)

# %% [markdown]
# ## Summary
#
# - Accuracy: **0.9703**
# - Loss: **0.06617**
# - Epoch: 15/50
