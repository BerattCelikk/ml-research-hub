# %% [markdown]
# # 🔁 Transfer Learning
#
# **Session:** 2026-05-04-22-42-55-ibb1
# **Date:** 2026-05-04

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

EXP_ID = "2026-05-04-22-42-55-ibb1"
TOPIC = "Transfer Learning"
print(f"Experiment: {EXP_ID}")

# %%
config = {
  "topic": "transfer-learning",
  "learning_rate": 0.001,
  "batch_size": 32,
  "epochs": 50,
  "optimizer": "adam",
  "seed": 66
}
print(config)

# %%
# Results
results = {
  "accuracy": 0.8722,
  "loss": 0.06412,
  "iterations": 3394,
  "epoch": 27
}
print("Results:", results)

# %% [markdown]
# ## Summary
#
# - Accuracy: **0.8722**
# - Loss: **0.06412**
# - Epoch: 27/50
