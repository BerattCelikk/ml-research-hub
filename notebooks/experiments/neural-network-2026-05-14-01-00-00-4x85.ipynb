# %% [markdown]
# # 🔬 Neural Network
#
# **Session:** 2026-05-14-01-00-00-4x85
# **Date:** 2026-05-14

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

EXP_ID = "2026-05-14-01-00-00-4x85"
TOPIC = "Neural Network"
print(f"Experiment: {EXP_ID}")

# %%
config = {
  "topic": "neural-network",
  "learning_rate": 0.0003,
  "batch_size": 16,
  "epochs": 50,
  "optimizer": "adam",
  "seed": 77
}
print(config)

# %%
# Results
results = {
  "accuracy": 0.9328,
  "loss": 0.04434,
  "iterations": 3308,
  "epoch": 38
}
print("Results:", results)

# %% [markdown]
# ## Summary
#
# - Accuracy: **0.9328**
# - Loss: **0.04434**
# - Epoch: 38/50
