# %% [markdown]
# # 🔁 Transfer Learning
#
# **Session:** 2026-05-04-22-43-10-q7yt
# **Date:** 2026-05-04

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

EXP_ID = "2026-05-04-22-43-10-q7yt"
TOPIC = "Transfer Learning"
print(f"Experiment: {EXP_ID}")

# %%
config = {
  "topic": "transfer-learning",
  "learning_rate": 0.001,
  "batch_size": 32,
  "epochs": 50,
  "optimizer": "adam",
  "seed": 66
}
print(config)

# %%
# Results
results = {
  "accuracy": 0.9765,
  "loss": 0.07787,
  "iterations": 3394,
  "epoch": 27
}
print("Results:", results)

# %% [markdown]
# ## Summary
#
# - Accuracy: **0.9765**
# - Loss: **0.07787**
# - Epoch: 27/50
