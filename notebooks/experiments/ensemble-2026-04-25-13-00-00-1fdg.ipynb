# %% [markdown]
# # 🎭 Ensemble Methods
#
# **Session:** 2026-04-25-13-00-00-1fdg
# **Date:** 2026-04-25

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

EXP_ID = "2026-04-25-13-00-00-1fdg"
TOPIC = "Ensemble Methods"
print(f"Experiment: {EXP_ID}")

# %%
config = {
  "topic": "ensemble",
  "learning_rate": 0.003,
  "batch_size": 32,
  "epochs": 50,
  "optimizer": "adam",
  "seed": 57
}
print(config)

# %%
# Results
results = {
  "accuracy": 0.9351,
  "loss": 0.06606,
  "iterations": 3124,
  "epoch": 18
}
print("Results:", results)

# %% [markdown]
# ## Summary
#
# - Accuracy: **0.9351**
# - Loss: **0.06606**
# - Epoch: 18/50
