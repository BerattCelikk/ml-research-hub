# %% [markdown]
# # 🔁 Transfer Learning
#
# **Session:** 2026-05-10-01-04-51-l8mj
# **Date:** 2026-05-10

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

EXP_ID = "2026-05-10-01-04-51-l8mj"
TOPIC = "Transfer Learning"
print(f"Experiment: {EXP_ID}")

# %%
config = {
  "topic": "transfer-learning",
  "learning_rate": 0.0003,
  "batch_size": 32,
  "epochs": 50,
  "optimizer": "adam",
  "seed": 73
}
print(config)

# %%
# Results
results = {
  "accuracy": 0.8840,
  "loss": 0.04069,
  "iterations": 3240,
  "epoch": 34
}
print("Results:", results)

# %% [markdown]
# ## Summary
#
# - Accuracy: **0.8840**
# - Loss: **0.04069**
# - Epoch: 34/50
