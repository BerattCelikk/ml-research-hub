# %% [markdown]
# # 📈 Visualization
#
# **Session:** 2026-05-14-22-00-00-wyp7
# **Date:** 2026-05-14

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

EXP_ID = "2026-05-14-22-00-00-wyp7"
TOPIC = "Visualization"
print(f"Experiment: {EXP_ID}")

# %%
config = {
  "topic": "visualization",
  "learning_rate": 0.001,
  "batch_size": 256,
  "epochs": 50,
  "optimizer": "adam",
  "seed": 76
}
print(config)

# %%
# Results
results = {
  "accuracy": 0.8624,
  "loss": 0.03991,
  "iterations": 3564,
  "epoch": 37
}
print("Results:", results)

# %% [markdown]
# ## Summary
#
# - Accuracy: **0.8624**
# - Loss: **0.03991**
# - Epoch: 37/50
