# %% [markdown]
# # 📉 Regression
#
# **Session:** 2026-04-30-13-00-00-815u
# **Date:** 2026-04-30

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

EXP_ID = "2026-04-30-13-00-00-815u"
TOPIC = "Regression"
print(f"Experiment: {EXP_ID}")

# %%
config = {
  "topic": "regression",
  "learning_rate": 0.003,
  "batch_size": 256,
  "epochs": 50,
  "optimizer": "adam",
  "seed": 62
}
print(config)

# %%
# Results
results = {
  "accuracy": 0.9675,
  "loss": 0.01619,
  "iterations": 3209,
  "epoch": 23
}
print("Results:", results)

# %% [markdown]
# ## Summary
#
# - Accuracy: **0.9675**
# - Loss: **0.01619**
# - Epoch: 23/50
